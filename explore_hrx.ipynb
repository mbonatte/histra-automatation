# %%
import os

from modelxml.xmlio import read_xml
from modelxml.selectors import foundation_interfaces

# %%
INPUT_FILE = r"Bridge_2_foundation.hrx"
INPUT_FILE = os.path.abspath(INPUT_FILE)

root = read_xml(INPUT_FILE)

# %%
foundations_interfaces = foundation_interfaces(root)

# %%
[f_i for f_i in foundations_interfaces[0][1] if float(f_i['VInt3D1'].split(';')[0]) < 440]
# Out:
# []
